# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

def generate_comparison_graph(data1, labels1, data2, labels2, fig_name = 'v0v1'):


    # color_dict = {'overlap': '#1f77b4', 'disagree':'#FF4136'}
    color_dict = {'overlap': 'c', 'disagree':'m'}

    color = [] 
    for label1, label2 in list(zip(labels1, labels2)):
        if label1 == label2:
            color.append(color_dict['overlap'])
        else:
            color.append(color_dict['disagree'])
    
    col_labels = list(color_dict.keys())
    handles = [plt.Rectangle((0,0),1,1, color=color_dict[label]) for label in col_labels]
    

    # Plotting the first chart
    fig, ax = plt.subplots(1, 2, figsize=(6, 4))#, gridspec_kw={'width_ratios': [1, 1]})
    ax[0].barh(labels1, data1, color= color)
    
    ax[0].set_title(fig_name[0:2])
    ax[0].invert_xaxis()
    ax[0].yaxis.tick_left()
    ax[0].set_xlabel("Rule Coverage", labelpad=20)
    ax[0].xaxis.set_label_coords(1.0, -0.1)

    #Reduce the distance between bars on the y axis
    ax[0].set_yticks(np.arange(len(labels1)))
    ax[0].set_yticklabels(labels1, fontdict={'fontsize': 8})

    # Plotting the second chart
    ax[1].barh(labels2, data2, color= color)#['#FF4136', '#1f77b4', '#3D9970', '#FF4136'])
    ax[1].set_title(fig_name[2:])
    ax[1].yaxis.tick_right()

    # Reduce the distance between bars on the y axis
    ax[1].set_yticks(np.arange(len(labels2)))
    ax[1].set_yticklabels(labels2, fontdict={'fontsize': 8})

    # Remove the gap between the two charts
    plt.subplots_adjust(wspace=0)
    plt.xlim(0,110)
    plt.legend(handles, col_labels)

    plt.show

    fig.savefig(f'model_comparison_{fig_name}.png', bbox_inches='tight')

# %%
# Data for the first chart
data_1 = [0, 5, 10, 99]
labels_1 = ['None', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).',
     'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 'R0: active(A) :- ind1(A,1.0)']

# Data for the second chart
data_2 = [10, 19, 29, 36]
labels_2 = ['R3: active(A) :- atm(A,B,c,14,C), bond(A,D,E,1),\n bond(A,F,D,2).', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).', 'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 
    'R0: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).']

data_3 = [0, 0, 0, 0, 0, 5, 10, 99]
labels_3 = ['None', 'None ', ' None', 'None.', '.None', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).',
     'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 'R0: active(A) :- ind1(A,1.0)']
# Data for the second chart
data_4 = [7,9, 9,16, 19, 26, 29, 42]
labels_4 = ['R6: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1), \nbond(A,F,D,2).', 'R5: active(A) :- ball3(A,B).', 'R5: active(A) :- carbon_5_aromatic_ring(A,B).', 'R4: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).', 
           'R3: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1), \nbond(A,F,D,2).', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).', 'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 
           'R0: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).']

generate_comparison_graph(data_1, labels_1, data_2, labels_2, fig_name = 'v0v1')

# %% [markdown]
# # Test

# %%
data_3 = [99, 99, 99, 99, 99, 5, 10, 99]
labels_3 = ['Non', 'Non', 'Non', 'Non', 'Non', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1), \nbond(A,F,D,2).',
     'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1), \nring_size_5(A,E)', 'R0: active(A) :- ind1(A,1.0)']
# labels_3 = ['jh', 'None', 'None', 'R4: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).', 
#            'R3: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1), \nbond(A,F,D,2).', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).', 'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 
#            'R0: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).']

data_4 = [7,9, 12,16, 19, 26, 29, 42]
labels_4 = ['R6: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1), \nbond(A,F,D,2).', 'R5: active(A) :- ball3(A,B).', 'R5: active(A) :- carbon_5_aromatic_ring(A,B).', 'R4: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).', 
           'R3: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1), \nbond(A,F,D,2).', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).', 'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 
           'R0: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).']
plt.barh(labels_3, data_3)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# # Difference Matrix

# %%
z = [[0.00, -4.46, 0.81],
     [4.46, 0.000, -1.42],
     [-0.81, 1.42, 0.00]]

#dict(x="Day of Week", y="Time of Day", color="Accuracy"),
fig = px.imshow(z, x=['v1', 'v2', 'v3'], y=['v1', 'v2', 'v3'], text_auto=True,
                    color_continuous_scale='oranges')
fig.update_xaxes(side="top")
go.Scatter(mode="markers", x=x_patch, y=y_patch, marker_symbol=[101],
                   marker_color="darkgray", 
                   marker_line_width=2, marker_size=22, hovertemplate= 'x: %{x}<br>y: %{y}<br>z: %{z}<extra></extra>'))
fig.show()
# fig.savefig('diff-matrix.png', bbox_inches='tight')

# %%
import plotly.express as px

z = [[.1, .3, .5, .7, .9],
     [1, .8, .6, .4, .2],
     [.2, 0, .1, .1, .9],
     [.9, .8, .4, .2, 0],
     [.3, .4, .5, .7, 1]]

fig = px.imshow(z, text_auto=True)
fig.show()

# %%
def generate_comparison_graph(plot_type = 1):

    if plot_type == 1:

        data1 = [0, 5, 10, 99]
        labels1 = ['None', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).',
            'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 'R0: active(A) :- ind1(A,1.0)']

        # Data for the second chart
        data2 = [10, 19, 29, 36]
        labels2 = ['R3: active(A) :- atm(A,B,c,14,C), bond(A,D,E,1),\n bond(A,F,D,2).', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).', 'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 
            'R0: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).']
        fig_name = 'v0v1'

    else:
        data1 = [0, 0, 0, 0, 0, 5, 10, 99]
        labels1 = ['None', 'None ', ' None', 'None.', '.None', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).',
            'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 'R0: active(A) :- ind1(A,1.0)']
        # Data for the second chart
        data2 = [7,9, 9,16, 19, 26, 29, 42]
        labels2 = ['R6: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1), \nbond(A,F,D,2).', 'R5: active(A) :- ball3(A,B).', 'R5: active(A) :- carbon_5_aromatic_ring(A,B).', 'R4: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).', 
                'R3: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1), \nbond(A,F,D,2).', 'R2: active(A) :- atm(A,B,c,29,C), bond(A,D,E,1),\n bond(A,F,D,2).', 'R1: active(A) :- bond(A,B,C,2), bond(A,C,D,1),\n ring_size_5(A,E)', 
                'R0: active(A) :- atm(A,B,n,32,C), atm(A,D,o,40,C).']
        fig_name = 'v0v2'


    # color_dict = {'overlap': '#3D9970', 'disagree':'#FF4136'}
    color_dict = {'overlap': 'c', 'disagree':'m'}

    color = [] 
    for label1, label2 in list(zip(labels1, labels2)):
        if label1 == label2:
            color.append(color_dict['overlap'])
        else:
            color.append(color_dict['disagree'])
    
    col_labels = list(color_dict.keys())
    handles = [plt.Rectangle((0,0),1,1, color=color_dict[label]) for label in col_labels]
    

    # Plotting the first chart
    fig, ax = plt.subplots(1, 2, figsize=(8, 4))#, gridspec_kw={'width_ratios': [1, 1]})
    ax[0].barh(labels1, data1, color= color)
    
    ax[0].set_title(fig_name[0:2])
    ax[0].invert_xaxis()
    ax[0].yaxis.tick_left()
    ax[0].set_xlabel("Rule Coverage", labelpad=20)
    ax[0].xaxis.set_label_coords(1.0, -0.1)

    #Reduce the distance between bars on the y axis
    ax[0].set_yticks(np.arange(len(labels1)))
    ax[0].set_yticklabels(labels1, fontdict={'fontsize': 8})

    # Plotting the second chart
    ax[1].barh(labels2, data2, color= color)#['#FF4136', '#1f77b4', '#3D9970', '#FF4136'])
    ax[1].set_title(fig_name[2:])
    ax[1].yaxis.tick_right()

    # Reduce the distance between bars on the y axis
    ax[1].set_yticks(np.arange(len(labels2)))
    ax[1].set_yticklabels(labels2, fontdict={'fontsize': 8})

    # Remove the gap between the two charts
    plt.subplots_adjust(wspace=0)
    plt.xlim(0,110)
    plt.legend(handles, col_labels)

    # plt.show

    # fig.savefig(f'model_comparison_{fig_name}.png', bbox_inches='tight')
    return fig

# %%
# from utils.app_functions import *

fig = generate_comparison_graph(1)
